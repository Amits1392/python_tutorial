# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.array([0,6])
y = np.array([0,250])
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'o')
plt.show()

# %%
plt.plot(y)
plt.show()

# %%
x = [1,2,3,4,6,7,8,9,10,5]
y = [3,5,7,4,51,4,78,90,8]
plt.plot(y,marker = 'o')
plt.show()

# %%
plt.plot(y,marker = "*")

# %%
plt.plot(y,marker = "_")
plt.show()

# %%
plt.plot(y,'o:r')
plt.show()

# %%
plt.plot(y,'o--k')
plt.show()

# %%
plt.plot(y,'o-.y')
plt.show()

# %%
plt.plot(y,'o--m')
plt.show()

# %%
plt.plot(y,marker = 'o',ms = 20)
plt.show()

# %%
plt.plot(y,marker = 'o',ms = 50)
plt.show()

# %%
plt.plot(y,marker = 'o',ms = 20,mec = 'y')
plt.show()

# %%
plt.plot(y,marker = 'o',ms = 20,mfc = 'y')
plt.show()

# %%
plt.plot(y,marker = 'o',ms = 20,mec = 'k',mfc = 'y')
plt.show()

# %%
plt.plot(y,marker = 'o',ms = 20,mec = 'hotpink',mfc ='hotpink')
plt.show()

# %%
plt.plot(y,linestyle = 'dotted')
plt.show()

# %%
plt.plot(y,linestyle = 'dashed')
plt.show()

# %%
plt.plot(y,ls= ":")
plt.show()

# %%
plt.plot(y,c ='r')
plt.show()

# %%
plt.plot(y,c ='r',linewidth = '20')
plt.show()

# %%
plt.plot(x,c= 'b')
plt.plot(y,c ='r')
plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y)
plt.xlabel('Average Pulse')
plt.ylabel("Calorie Burnage")
plt.title("Helth Tip")
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}



plt.xlabel('Average Pulse',fontdict = font1)
plt.ylabel("Calorie Burnage",fontdict = font2)
plt.title("Helth Tip",fontdict = font2)

plt.plot(x,y)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}



plt.xlabel('Average Pulse',fontdict = font1)
plt.ylabel("Calorie Burnage",fontdict = font2)
plt.title("Helth Tip",fontdict = font2,loc = 'left')

plt.plot(x,y)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y)
plt.xlabel('Average Pulse')
plt.ylabel("Calorie Burnage")
plt.title("Helth Tip")
plt.grid()
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y)
plt.xlabel('Average Pulse')
plt.ylabel("Calorie Burnage")
plt.title("Helth Tip")
plt.grid(axis = 'x')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y)
plt.xlabel('Average Pulse')
plt.ylabel("Calorie Burnage")
plt.title("Helth Tip")
plt.grid(color = 'green',linestyle = ':',linewidth = 1)
plt.show()

# %%
xx = np.array([0, 1, 2, 3])
yy = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(xx,yy)

xx1 = np.array([0, 1, 2, 3])
yy1 = np.array([10, 20, 30, 40])

plt.subplot(2,1 , 2)
plt.plot(xx1,yy1)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.scatter(x1,y1)
plt.scatter(xx1,yy1)
plt.legend()
plt.colorbar()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
plt.barh(x,y)
plt.show()

# %%
plt.bar(x,y,color = 'green')
plt.show()

# %%
plt.bar(x,y,color = 'hotpink')
plt.show()

# %%
plt.bar(x,y,color = 'green',width = 1.5)
plt.show()

# %%
plt.barh(x,y,color = 'green',height = 1.5)
plt.show()

# %%
x = np.random.normal(170,10,250)
print(x)
# Out:
# [168.73390887 157.80338678 175.41473496 181.41154218 147.0593049
#  154.34069844 174.03102213 144.61304798 167.94861188 169.17112984
#  172.12885495 164.54395588 177.42154073 175.47046278 186.3746873
#  172.62306591 181.35556214 162.33529418 155.16354909 183.92851205
#  146.24393428 167.59757202 182.60774673 169.9781195  174.71542091
#  166.80432756 162.01785284 181.44828244 174.15457278 161.396273
#  162.76309848 173.86312413 184.52317141 151.37918759 176.61127733
#  168.16108832 169.23249062 165.78825463 154.83264533 167.78531885
#  183.58196185 173.81089844 166.4212213  177.62498323 161.92754195
